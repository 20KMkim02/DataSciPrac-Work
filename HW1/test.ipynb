# %%
https://www.imdb.com/chart/top/

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

genres = ["action", "adventure", "animation", "anime", "biography", 
          "comedy", "crime", "documentary", "drama", "entertainment", 
          "faith_and_spirituality", "fantasy", "game_show", "lgbtq+", 
          "health_and_wellness", "history", "holiday", "horror", "house_and_garden", 
          "kids_and_family", "music", "musical", "mystery_and_thriller", "nature", "news", 
          "reality", "romance", "sci-fi", "short", "soap", "special_interest", "sports", 
          "stand-up", "talk_show", "travel", "variety", "war", "western"]


url='https://www.rottentomatoes.com/browse/movies_at_home/genres:{i}?page=1'
r= requests.get(url)
data=r.text
soup = BeautifulSoup(data, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Hello there, HTML enthusiast! -->
# <!-- DCR commit hash 56aa76e15e2f4433d51648b2a36e025648f7a6fc -->
# <title>Latest news, sport and opinion from the Guardian</title>
# <meta content="Latest international news, sport and comment from the Guardian" name="description"/>
# <meta charset="utf-8"/>
# <link href="https://www.theguardian.com" rel="canonical"/>
# <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
# <meta content="#052962" name="theme-color">
# <link href="https://assets.guim.co.uk/static/frontend/manifest.json" rel="manifest"/>
# <link href="https://assets.guim.co.uk/static/frontend/icons/homescreen/apple-touch-icon.svg" rel="apple-touch-icon" sizes="any"/>
# <link href="https://assets.guim.co.uk/static/frontend/icons/homescreen/apple-touch-icon-512.png" rel="apple-touch-icon" sizes="512x512"/>
# ...
